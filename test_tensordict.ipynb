# %%
from tensordict.tensordict import TensorDict
from tensordict import TensorDict

# %%
class Frames(TensorDict):
    pass

class Frame(TensorDict):
    
    def __init__(self):
        super().__init__({
            'atoms': TensorDict(),
            'pairs': TensorDict()
        })
