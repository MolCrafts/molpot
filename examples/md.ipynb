# %%
import torch
import molpot as mpot

# %%
integrator = mpot.md.integrator.VelocityVerlet(1.0)
calculator = lambda x: None
md = mpot.engine.MoleculeDymanics(
    integrator,
    calculator
    work_dir='md')
